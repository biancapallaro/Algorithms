# %% [markdown]
# # Finding surveillance planes using classification
#
# **The story:**
#
# - https://www.buzzfeednews.com/article/peteraldhous/spies-in-the-skies
# - https://www.buzzfeednews.com/article/peteraldhous/hidden-spy-planes
#
# This story, done by Peter Aldhous at Buzzfeed News, involved training a machine learning algorithm to recognize government surveillance planes based on what their flight patterns look like.
#
# **Datasets**
#
# * **feds.csv:** Transponder codes of planes operated by the federal government
# * **planes_features.csv:** various features describing each plane's flight patterns
# * **train.csv:** a labeled dataset of transponder codes and whether each plane is a surveillance plane or not
#     - The `label` column was originally `class`, but I renamed it because pandas freaks out a bit with a column named `class`
#     - This was created by Buzzfeed `feds.csv`
# * **data dictionary:** You can find the data dictionary published with their analysis [here](https://buzzfeednews.github.io/2016-04-federal-surveillance-planes/analysis.html)
# * **a few other files**
#
# ## What's the goal?
#
# The FBI and Department of Homeland Security operate many planes that are not directly labeled as belonging to the government. If we can uncover these planes, we have a better idea of the surveillance activities they are undertaking.

# %% [markdown]
# ## Imports
#
# Also set a large number of maximum columns.

# %%
import pandas as pd

pd.set_option("display.max_columns", 100)

# %% [markdown]
# # Read in our data
#
# Almost all classification problems start with a set of labeled features. In this case, the features are in one CSV file and the labels are in another. **Read both files in and merge them on `adshex`, the transpoder code.**

# %%
# Read in your features
features = pd.read_csv("planes_features.csv")
features.head()
# Out:
#    adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 0       A   0.120253   0.075949   0.183544   0.335443   0.284810  0.088608
# 1  A00000   0.211735   0.155612   0.181122   0.198980   0.252551  0.204082
# 2  A00002   0.517241   0.103448   0.103448   0.103448   0.172414  0.862069
# 3  A00008   0.125000   0.041667   0.208333   0.166667   0.458333  0.125000
# 4  A0001E   0.100000   0.200000   0.200000   0.400000   0.100000  0.100000
#
#      boxes2    boxes3    boxes4    boxes5    speed1    speed2    speed3  \
# 0  0.044304  0.069620  0.120253  0.677215  0.021824  0.020550  0.062330
# 1  0.183673  0.168367  0.173469  0.267857  0.107348  0.143410  0.208139
# 2  0.137931  0.000000  0.000000  0.000000  0.990792  0.000921  0.000000
# 3  0.083333  0.125000  0.166667  0.500000  0.187960  0.278952  0.221048
# 4  0.000000  0.100000  0.400000  0.400000  0.007937  0.026984  0.084127
#
#      speed4    speed5  altitude1  altitude2  altitude3  altitude4  altitude5  \
# 0  0.100713  0.794582   0.042374   0.060971   0.066831   0.106403   0.723421
# 1  0.177013  0.364090   0.177318   0.114457   0.129648   0.197694   0.380882
# 2  0.000000  0.008287   0.599448   0.400552   0.000000   0.000000   0.000000
# 3  0.190257  0.121783   0.014706   0.053309   0.149816   0.279871   0.502298
# 4  0.179365  0.701587   0.041270   0.085714   0.039683   0.111111   0.722222
#
#      steer1    steer2    steer3    steer4    steer5    steer6    steer7  \
# 0  0.020211  0.048913  0.270550  0.344090  0.097317  0.186651  0.011379
# 1  0.034976  0.048127  0.240732  0.356314  0.116116  0.159325  0.012828
# 2  0.105893  0.090239  0.174954  0.244015  0.034070  0.202578  0.021179
# 3  0.029871  0.044118  0.202665  0.380515  0.094669  0.182904  0.014706
# 4  0.019048  0.049206  0.249206  0.326984  0.112698  0.206349  0.012698
#
#      steer8  flights  squawk_1  observations  type
# 0  0.009426      158         0         11776  GRND
# 1  0.013628      392         0         52465  TBM7
# 2  0.068140       29         0          1086  SHIP
# 3  0.020221       24         0          2176  PA46
# 4  0.011111       10      1135           630  C56X

# %%
# Read in your labels
labeled = pd.read_csv("train.csv").rename(columns={'class': 'label'})
labeled.head()
# Out:
#    adshex    label
# 0  A00C4B  surveil
# 1  A0AB21  surveil
# 2  A0AE77  surveil
# 3  A0AE7C  surveil
# 4  A0C462  surveil

# %%
# We're merging with how='right' to keep the rows that do NOT have a match in the training dataset
df = labeled.merge(features, on='adshex', how='right')
df.head()
# Out:
#    adshex  label  duration1  duration2  duration3  duration4  duration5  \
# 0       A    NaN   0.120253   0.075949   0.183544   0.335443   0.284810
# 1  A00000    NaN   0.211735   0.155612   0.181122   0.198980   0.252551
# 2  A00002  other   0.517241   0.103448   0.103448   0.103448   0.172414
# 3  A00008    NaN   0.125000   0.041667   0.208333   0.166667   0.458333
# 4  A0001E    NaN   0.100000   0.200000   0.200000   0.400000   0.100000
#
#      boxes1    boxes2    boxes3    boxes4    boxes5    speed1    speed2  \
# 0  0.088608  0.044304  0.069620  0.120253  0.677215  0.021824  0.020550
# 1  0.204082  0.183673  0.168367  0.173469  0.267857  0.107348  0.143410
# 2  0.862069  0.137931  0.000000  0.000000  0.000000  0.990792  0.000921
# 3  0.125000  0.083333  0.125000  0.166667  0.500000  0.187960  0.278952
# 4  0.100000  0.000000  0.100000  0.400000  0.400000  0.007937  0.026984
#
#      speed3    speed4    speed5  altitude1  altitude2  altitude3  altitude4  \
# 0  0.062330  0.100713  0.794582   0.042374   0.060971   0.066831   0.106403
# 1  0.208139  0.177013  0.364090   0.177318   0.114457   0.129648   0.197694
# 2  0.000000  0.000000  0.008287   0.599448   0.400552   0.000000   0.000000
# 3  0.221048  0.190257  0.121783   0.014706   0.053309   0.149816   0.279871
# 4  0.084127  0.179365  0.701587   0.041270   0.085714   0.039683   0.111111
#
#    altitude5    steer1    steer2    steer3    steer4    steer5    steer6  \
# 0   0.723421  0.020211  0.048913  0.270550  0.344090  0.097317  0.186651
# 1   0.380882  0.034976  0.048127  0.240732  0.356314  0.116116  0.159325
# 2   0.000000  0.105893  0.090239  0.174954  0.244015  0.034070  0.202578
# 3   0.502298  0.029871  0.044118  0.202665  0.380515  0.094669  0.182904
# 4   0.722222  0.019048  0.049206  0.249206  0.326984  0.112698  0.206349
#
#      steer7    steer8  flights  squawk_1  observations  type
# 0  0.011379  0.009426      158         0         11776  GRND
# 1  0.012828  0.013628      392         0         52465  TBM7
# 2  0.021179  0.068140       29         0          1086  SHIP
# 3  0.014706  0.020221       24         0          2176  PA46
# 4  0.012698  0.011111       10      1135           630  C56X

# %% [markdown]
# Confirm you have 19,799 rows and 34 columns.

# %%
df.shape
# Out:
# (19799, 34)

# %% [markdown]
# # Cleaning up our data
#
# ## Number-izing our labels
#
# Each row is a plane, and it's marked as either a surveillance plane, not a surveillance plane, or missing a label. How many do we have in each category?

# %%
df.label.value_counts(dropna=False)
# Out:
# NaN        19202
# other        500
# surveil       97
# Name: label, dtype: int64

# %% [markdown]
# How do you feel about that split?
#
# What is the difference between `other` and `NaN`?
#
# **Prepare this column for machine learning.** What's wrong with it as `"surveil"` and `"other"`? Add a new column that we can use for classification.

# %%
df['is_surveil'] = (df.label.dropna() == 'surveil').astype(int)
df.head()
# Out:
#    adshex  label  duration1  duration2  duration3  duration4  duration5  \
# 0       A    NaN   0.120253   0.075949   0.183544   0.335443   0.284810
# 1  A00000    NaN   0.211735   0.155612   0.181122   0.198980   0.252551
# 2  A00002  other   0.517241   0.103448   0.103448   0.103448   0.172414
# 3  A00008    NaN   0.125000   0.041667   0.208333   0.166667   0.458333
# 4  A0001E    NaN   0.100000   0.200000   0.200000   0.400000   0.100000
#
#      boxes1    boxes2    boxes3    boxes4    boxes5    speed1    speed2  \
# 0  0.088608  0.044304  0.069620  0.120253  0.677215  0.021824  0.020550
# 1  0.204082  0.183673  0.168367  0.173469  0.267857  0.107348  0.143410
# 2  0.862069  0.137931  0.000000  0.000000  0.000000  0.990792  0.000921
# 3  0.125000  0.083333  0.125000  0.166667  0.500000  0.187960  0.278952
# 4  0.100000  0.000000  0.100000  0.400000  0.400000  0.007937  0.026984
#
#      speed3    speed4    speed5  altitude1  altitude2  altitude3  altitude4  \
# 0  0.062330  0.100713  0.794582   0.042374   0.060971   0.066831   0.106403
# 1  0.208139  0.177013  0.364090   0.177318   0.114457   0.129648   0.197694
# 2  0.000000  0.000000  0.008287   0.599448   0.400552   0.000000   0.000000
# 3  0.221048  0.190257  0.121783   0.014706   0.053309   0.149816   0.279871
# 4  0.084127  0.179365  0.701587   0.041270   0.085714   0.039683   0.111111
#
#    altitude5    steer1    steer2    steer3    steer4    steer5    steer6  \
# 0   0.723421  0.020211  0.048913  0.270550  0.344090  0.097317  0.186651
# 1   0.380882  0.034976  0.048127  0.240732  0.356314  0.116116  0.159325
# 2   0.000000  0.105893  0.090239  0.174954  0.244015  0.034070  0.202578
# 3   0.502298  0.029871  0.044118  0.202665  0.380515  0.094669  0.182904
# 4   0.722222  0.019048  0.049206  0.249206  0.326984  0.112698  0.206349
#
#      steer7    steer8  flights  squawk_1  observations  type  is_surveil
# 0  0.011379  0.009426      158         0         11776  GRND         NaN
# 1  0.012828  0.013628      392         0         52465  TBM7         NaN
# 2  0.021179  0.068140       29         0          1086  SHIP         0.0
# 3  0.014706  0.020221       24         0          2176  PA46         NaN
# 4  0.012698  0.011111       10      1135           630  C56X         NaN

# %% [markdown]
# # Building our classifier
#
# When we're about to classify, we usually just drop our target column to build our inputs and outputs:
#
# ```python
# X = train_df.drop(column='column_you_are_predicting')
# y = train_df.column_you_are_predicting
# ```
#
# This time is a little different. First, we have unlabeled data in there! Use `.dropna()` to filter your training data so we only have labeled data.

# %%
train_df = df.dropna()
train_df.shape
# Out:
# (597, 35)

# %% [markdown]
# We also have a few extra columns that we aren't using for classification (like the text version of the type column and the transponder code). **We don't need to remove them now:** it's fine to drop multiple columns here that you aren't using, just a little bit messier. You also have to make sure you're dropping all the right ones.
#
# Do a `.head()` to double-check all of the columns you need to drop when creating your `X`.

# %%
df.head(2)
# Out:
#    adshex label  duration1  duration2  duration3  duration4  duration5  \
# 0       A   NaN   0.120253   0.075949   0.183544   0.335443   0.284810
# 1  A00000   NaN   0.211735   0.155612   0.181122   0.198980   0.252551
#
#      boxes1    boxes2    boxes3    boxes4    boxes5    speed1   speed2  \
# 0  0.088608  0.044304  0.069620  0.120253  0.677215  0.021824  0.02055
# 1  0.204082  0.183673  0.168367  0.173469  0.267857  0.107348  0.14341
#
#      speed3    speed4    speed5  altitude1  altitude2  altitude3  altitude4  \
# 0  0.062330  0.100713  0.794582   0.042374   0.060971   0.066831   0.106403
# 1  0.208139  0.177013  0.364090   0.177318   0.114457   0.129648   0.197694
#
#    altitude5    steer1    steer2    steer3    steer4    steer5    steer6  \
# 0   0.723421  0.020211  0.048913  0.270550  0.344090  0.097317  0.186651
# 1   0.380882  0.034976  0.048127  0.240732  0.356314  0.116116  0.159325
#
#      steer7    steer8  flights  squawk_1  observations  type  is_surveil
# 0  0.011379  0.009426      158         0         11776  GRND         NaN
# 1  0.012828  0.013628      392         0         52465  TBM7         NaN

# %% [markdown]
# ### Create your `X` and `y`.
#
# When you do `train_df.drop`, you'll want to remove more than just your `0`/`1` surveillance label. What other columns do you not want to use as input? Maybe some categories you converted into codes?

# %%
X = train_df.drop(columns=['adshex', 'label', 'type', 'is_surveil'])
y = train_df.is_surveil

# %% [markdown]
# Triple-check that `X` is a list of numeric features and and `y` is a numeric label.

# %%
X.head(2)
# Out:
#     duration1  duration2  duration3  duration4  duration5    boxes1    boxes2  \
# 2    0.517241   0.103448   0.103448   0.103448   0.172414  0.862069  0.137931
# 29   0.000000   0.254902   0.176471   0.313725   0.254902  0.058824  0.372549
#
#       boxes3    boxes4    boxes5    speed1    speed2    speed3    speed4  \
# 2   0.000000  0.000000  0.000000  0.990792  0.000921  0.000000  0.000000
# 29  0.294118  0.215686  0.058824  0.052650  0.191676  0.419769  0.329805
#
#       speed5  altitude1  altitude2  altitude3  altitude4  altitude5    steer1  \
# 2   0.008287   0.599448   0.400552   0.000000   0.000000   0.000000  0.105893
# 29  0.006099   0.244327   0.235985   0.123329   0.307023   0.089335  0.034801
#
#       steer2    steer3    steer4   steer5    steer6    steer7    steer8  \
# 2   0.090239  0.174954  0.244015  0.03407  0.202578  0.021179  0.068140
# 29  0.038389  0.263342  0.375998  0.13203  0.120011  0.008611  0.006906
#
#     flights  squawk_1  observations
# 2        29         0          1086
# 29       51         0         11149

# %%
y.head(2)
# Out:
# 2     0.0
# 29    0.0
# Name: is_surveil, dtype: float64

# %% [markdown]
# ### Split into test and train datasets
#
# We could be nice and lazy and use all our data for training, but it just isn't right! Taking a test using the exact same questions you studied is just cheating. Split your data into test and train.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# # Classify using a logistic classifier
#
# ## Train your classifier
#
# Build a `LogisticRegression` and fit it to your data, making sure you're training using only `X_train` and `y_train`.
#
# * **Tip:** You'll want to give `LogisticRegression` an extra argument of `max_iter=4000` - it means "work a little harder than you expect," because otherwise it won't find an answer (by default it only has a `max_iter` of 100)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(C=1e9, solver='lbfgs', max_iter=4000)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1000000000.0, max_iter=4000)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9466666666666667

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['not surveil', 'surveil'])
pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                 Predicted not surveil  Predicted surveil
# Is not surveil                    125                  6
# Is surveil                          2                 17

# %% [markdown]
# ## Examine the coefficients
#
# What does it mean? What features is the classifier using? Do you care about the odds ratio? **What is even the point of this `LogisticRegression` thing?**

# %%
import numpy as np

feature_names = X.columns
coefficients = clf.coef_[0]

pd.DataFrame({
    'feature': feature_names,
    'coefficient (log odds ratio)': coefficients,
    'odds ratio': np.exp(coefficients)
}).sort_values(by='odds ratio', ascending=False)
# Out:
#          feature  coefficient (log odds ratio)  odds ratio
# 21        steer2                      3.387038   29.578218
# 17     altitude3                      2.841694   17.144791
# 5         boxes1                      2.253505    9.521045
# 19     altitude5                      2.077599    7.985275
# 20        steer1                      1.937424    6.940850
# 0      duration1                      1.759796    5.811253
# 6         boxes2                      1.465808    4.331040
# 18     altitude4                      1.347521    3.847876
# 4      duration5                      0.769442    2.158561
# 11        speed2                      0.550424    1.733989
# 10        speed1                      0.256094    1.291874
# 27        steer8                      0.024304    1.024602
# 29      squawk_1                      0.000483    1.000483
# 30  observations                      0.000017    1.000017
# 26        steer7                     -0.004864    0.995147
# 28       flights                     -0.006149    0.993870
# 7         boxes3                     -0.141738    0.867848
# 22        steer3                     -0.209880    0.810682
# 12        speed3                     -0.251823    0.777382
# 1      duration2                     -0.378841    0.684655
# 14        speed5                     -0.766188    0.464782
# 2      duration3                     -1.111037    0.329217
# 8         boxes4                     -1.126588    0.324137
# 13        speed4                     -1.630172    0.195896
# 24        steer5                     -1.790868    0.166815
# 25        steer6                     -1.881480    0.152364
# 16     altitude2                     -2.700658    0.067161
# 3      duration4                     -2.881025    0.056077
# 23        steer4                     -3.606268    0.027153
# 9         boxes5                     -4.292650    0.013669
# 15     altitude1                     -5.407822    0.004481

# %% [markdown]
# If we don't care about the odds ratio, using the `eli5` package can shrink our code by a lot (and give us color!)

# %% [markdown]
# ## How well does our classifier perform?
#
# Let's take a look at the confusion matrix to see how well this classifier finds surveillance planes. Make sure you're using `y_test` and `X_test`, not the full dataset.

# %% [markdown]
# # Classify using a decision tree
#
# Now we'll use a decision tree. This is how you make one:
#
# ```python
# from sklearn.tree import DecisionTreeClassifier
#
# clf = DecisionTreeClassifier()
# ```
#
# But it's up to you to teach it what spy planes look like using your training data.
#
# If we use `max_depth=` to limit the depth of the tree, it will help us visualize it. For example, `max_depth=5` will only allow the tree to make five decisions.
#
# Make a decision tree and fit it to your data. Use a `max_depth=` of something between 2 to 5.

# %%
# from sklearn.linear_model import LogisticRegression

# clf = LogisticRegression(C=1e9, solver='lbfgs', max_iter=4000)
# clf.fit(X, y)

from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=5)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9733333333333334

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['not surveil', 'surveil'])
pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                 Predicted not surveil  Predicted surveil
# Is not surveil                    127                  4
# Is surveil                          0                 19

# %%
# !pip install eli5
# !brew install graphviz
#import eli5
# Out:
# Requirement already satisfied: eli5 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: attrs>16.0.0 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (19.3.0)
# Requirement already satisfied: scikit-learn>=0.20 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (0.23.1)
# Requirement already satisfied: scipy in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (1.4.1)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (0.8.9)
# Requirement already satisfied: numpy>=1.9.0 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (1.18.5)
# Requirement already satisfied: jinja2 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (2.11.2)
# Requirement already satisfied: graphviz in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (0.16)
# Requirement already satisfied: six in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from eli5) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from scikit-learn>=0.20->eli5) (0.15.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/soma/.pyenv/versions/3.8.2/lib/python3.8/site-packages (from jinja2->eli5) (1.1.1)
# WARNING: You are using pip version 19.2.3, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 3 taps (phinze/cask, homebrew/core and homebrew/cask).
# ==> New Formulae
# cyrus-sasl          oras                qt-percona-server   tomcat@9
# enzyme              python-tabulate     qt-postgresql       wllvm
# gopass-jsonapi      qt-libiodbc         qt-unixodbc         xray
# klee                qt-mariadb          snowpack
# openmodelica        qt-mysql            sqlancer
# ==> Updated Formulae
# Updated 416 formulae.
# ==> New Casks
# code-composer-studio       mailtrackerblocker         simplelink-msp432e4-sdk
# code-composer-studio       mailtrackerblocker         simplelink-msp432e4-sdk
# devbook                    micro-sniff                uniflash
# devbook                    micro-sniff                uniflash
# devutils                   n1ghtshade                 veepn
# devutils                   n1ghtshade                 veepn
# goldenpassport             simplelink-msp432-sdk
# goldenpassport             simplelink-msp432-sdk
# ==> Updated Casks
# Updated 522 casks.
# ==> Deleted Casks
# insomnia-designer                        insomnia-designer
#
# ==> Downloading https://homebrew.bintray.com/bottles/gd-2.3.2.catalina.bottle.ta
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/aa93cd58d9694c8629944
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libffi-3.3_3.catalina.bottl
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/gdbm-1.19.catalina.bottle.t
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/a3e43170a1d8413e6817e
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/mpdecimal-2.5.1.catalina.bo
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/1a8314428019cec85756b
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/python%403.9-3.9.2_1.catali
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/65c25cb1486cbda7ce41c
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/jasper-2.0.26.catalina.bott
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/7ff4907367a4d6d0fa8f1
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/netpbm-10.86.19.catalina.bo
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/24d6ed86c8f4548ea414f
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/gts-0.7.6_2.catalina.bottle
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/8a0c9b4f60a2cbea2e2e3
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libpthread-stubs-0.4.catali
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/xorgproto-2021.3.catalina.b
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/386eeca1a9111911f4767
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libxau-1.0.9.catalina.bottl
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libxdmcp-1.1.3.catalina.bot
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libxcb-1.14_1.catalina.bott
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/7f40d617b2092e9dc4fed
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libx11-1.7.0.catalina.bottl
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/59b7a9aa7a99a4f725761
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libxext-1.3.4.catalina.bott
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/libxrender-0.9.10.catalina.
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/cairo-1.16.0_5.catalina.bot
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/4a117545953b9784f78db
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/gdk-pixbuf-2.42.2.catalina.
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/fe5c2b2bc7a942a6cab4d
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/icu4c-68.2.catalina.bottle.
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/fdc2f15705175478dc166
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/harfbuzz-2.7.4_1.catalina.b
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/9144906c46cc32dacfd8b
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/pango-1.48.2.catalina.bottl
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/29a36a8c3c7832a48e012
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/librsvg-2.50.3.catalina.bot
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/215a03b5e14c336df9ffd
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/graphviz-2.46.1.catalina.bo
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/ba5fd51f1c318e395ecbd
# ######################################################################## 100.0%
# ==> Installing dependencies for graphviz: gd, libffi, gdbm, mpdecimal, python@3.9, jasper, netpbm, gts, libpthread-stubs, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, cairo, gdk-pixbuf, icu4c, harfbuzz, pango and librsvg
# ==> Installing graphviz dependency: gd
# ==> Pouring gd-2.3.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gd/2.3.2: 35 files, 1.4MB
# ==> Installing graphviz dependency: libffi
# ==> Pouring libffi-3.3_3.catalina.bottle.tar.gz
# ==> Caveats
# libffi is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# For compilers to find libffi you may need to set:
#   export LDFLAGS="-L/usr/local/opt/libffi/lib"
#   export CPPFLAGS="-I/usr/local/opt/libffi/include"
#
# For pkg-config to find libffi you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/libffi/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/libffi/3.3_3: 17 files, 540.3KB
# ==> Installing graphviz dependency: gdbm
# ==> Pouring gdbm-1.19.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gdbm/1.19: 24 files, 788.8KB
# ==> Installing graphviz dependency: mpdecimal
# ==> Pouring mpdecimal-2.5.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/mpdecimal/2.5.1: 71 files, 2.1MB
# ==> Installing graphviz dependency: python@3.9
# ==> Pouring python@3.9-3.9.2_1.catalina.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /usr/local
# Could not symlink bin/2to3
# Target /usr/local/bin/2to3
# already exists. You may want to remove it:
#   rm '/usr/local/bin/2to3'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite python@3.9
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run python@3.9
#
# Possible conflicting files are:
# /usr/local/bin/2to3 -> /Library/Frameworks/Python.framework/Versions/2.7/bin/2to3
# /usr/local/bin/easy_install-3.9 -> /usr/local/Cellar/python@3.9/3.9.2/bin/easy_install-3.9
# /usr/local/bin/idle3 -> /Library/Frameworks/Python.framework/Versions/3.8/bin/idle3
# /usr/local/bin/pip3 -> /usr/local/Cellar/python@3.9/3.9.2/bin/pip3
# /usr/local/bin/pip3.9 -> /usr/local/Cellar/python@3.9/3.9.2/bin/pip3.9
# /usr/local/bin/pydoc3 -> /Library/Frameworks/Python.framework/Versions/3.8/bin/pydoc3
# /usr/local/bin/python3 -> /Library/Frameworks/Python.framework/Versions/3.8/bin/python3
# /usr/local/bin/python3-config -> /Library/Frameworks/Python.framework/Versions/3.8/bin/python3-config
# ==> /usr/local/Cellar/python@3.9/3.9.2_1/bin/python3 -m ensurepip
# ==> /usr/local/Cellar/python@3.9/3.9.2_1/bin/pip3 install -v --global-option=--n
# ==> /usr/local/Cellar/python@3.9/3.9.2_1/bin/pip3 wheel --wheel-dir=/usr/local/C
# ==> Caveats
# Python has been installed as
#   /usr/local/bin/python3
#
# Unversioned symlinks `python`, `python-config`, `pip` etc. pointing to
# `python3`, `python3-config`, `pip3` etc., respectively, have been installed into
#   /usr/local/opt/python@3.9/libexec/bin
#
# You can install Python packages with
#   pip3 install <package>
# They will install into the site-package directory
#   /usr/local/lib/python3.9/site-packages
#
# See: https://docs.brew.sh/Homebrew-and-Python
# ==> Summary
# 🍺  /usr/local/Cellar/python@3.9/3.9.2_1: 3,935 files, 65.9MB
# ==> Installing graphviz dependency: jasper
# ==> Pouring jasper-2.0.26.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/jasper/2.0.26: 40 files, 1015KB
# ==> Installing graphviz dependency: netpbm
# ==> Pouring netpbm-10.86.19.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/netpbm/10.86.19: 410 files, 17.7MB
# ==> Installing graphviz dependency: gts
# ==> Pouring gts-0.7.6_2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gts/0.7.6_2: 27 files, 1.1MB
# ==> Installing graphviz dependency: libpthread-stubs
# ==> Pouring libpthread-stubs-0.4.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libpthread-stubs/0.4: 5 files, 6.6KB
# ==> Installing graphviz dependency: xorgproto
# ==> Pouring xorgproto-2021.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/xorgproto/2021.3: 264 files, 3.9MB
# ==> Installing graphviz dependency: libxau
# ==> Pouring libxau-1.0.9.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxau/1.0.9: 20 files, 117.5KB
# ==> Installing graphviz dependency: libxdmcp
# ==> Pouring libxdmcp-1.1.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxdmcp/1.1.3: 11 files, 125.2KB
# ==> Installing graphviz dependency: libxcb
# ==> Pouring libxcb-1.14_1.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libxcb/1.14_1: 2,452 files, 6.9MB
# ==> Installing graphviz dependency: libx11
# ==> Pouring libx11-1.7.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libx11/1.7.0: 1,055 files, 7MB
# ==> Installing graphviz dependency: libxext
# ==> Pouring libxext-1.3.4.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxext/1.3.4: 87 files, 420.4KB
# ==> Installing graphviz dependency: libxrender
# ==> Pouring libxrender-0.9.10.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxrender/0.9.10: 12 files, 169.5KB
# ==> Installing graphviz dependency: cairo
# ==> Pouring cairo-1.16.0_5.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/cairo/1.16.0_5: 126 files, 6.3MB
# ==> Installing graphviz dependency: gdk-pixbuf
# ==> Pouring gdk-pixbuf-2.42.2.catalina.bottle.tar.gz
# ==> /usr/local/Cellar/gdk-pixbuf/2.42.2/bin/gdk-pixbuf-query-loaders --update-ca
# 🍺  /usr/local/Cellar/gdk-pixbuf/2.42.2: 149 files, 3.8MB
# ==> Installing graphviz dependency: icu4c
# ==> Pouring icu4c-68.2.catalina.bottle.tar.gz
# ==> Caveats
# icu4c is keg-only, which means it was not symlinked into /usr/local,
# because macOS provides libicucore.dylib (but nothing else).
#
# If you need to have icu4c first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/icu4c/bin:$PATH"' >> ~/.zshrc
#   echo 'export PATH="/usr/local/opt/icu4c/sbin:$PATH"' >> ~/.zshrc
#
# For compilers to find icu4c you may need to set:
#   export LDFLAGS="-L/usr/local/opt/icu4c/lib"
#   export CPPFLAGS="-I/usr/local/opt/icu4c/include"
#
# For pkg-config to find icu4c you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/icu4c/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/icu4c/68.2: 259 files, 72.5MB
# ==> Installing graphviz dependency: harfbuzz
# ==> Pouring harfbuzz-2.7.4_1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/harfbuzz/2.7.4_1: 68 files, 6.7MB
# ==> Installing graphviz dependency: pango
# ==> Pouring pango-1.48.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pango/1.48.2: 64 files, 3MB
# ==> Installing graphviz dependency: librsvg
# ==> Pouring librsvg-2.50.3.catalina.bottle.tar.gz
# ==> /usr/local/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /usr/local/Cellar/librsvg/2.50.3: 48 files, 141.5MB
# ==> Installing graphviz
# ==> Pouring graphviz-2.46.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/graphviz/2.46.1: 462 files, 12.2MB
# ==> Upgrading 3 dependents:
# imagemagick 7.0.11-1 -> 7.0.11-3, python@3.8 3.8.8 -> 3.8.8_1, youtube-dl 2021.2.22 -> 2021.3.3
# ==> Upgrading python@3.8 3.8.8 -> 3.8.8_1
# ==> Downloading https://homebrew.bintray.com/bottles/python%403.8-3.8.8_1.catali
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/898ace209da0f175407aa
# ######################################################################## 100.0%
# ==> Pouring python@3.8-3.8.8_1.catalina.bottle.tar.gz
# ==> /usr/local/Cellar/python@3.8/3.8.8_1/bin/python3 -s setup.py --no-user-cfg i
# ==> /usr/local/Cellar/python@3.8/3.8.8_1/bin/python3 -s setup.py --no-user-cfg i
# ==> /usr/local/Cellar/python@3.8/3.8.8_1/bin/python3 -s setup.py --no-user-cfg i
# ==> Caveats
# Python has been installed as
#   /usr/local/opt/python@3.8/bin/python3
#
# Unversioned symlinks `python`, `python-config`, `pip` etc. pointing to
# `python3`, `python3-config`, `pip3` etc., respectively, have been installed into
#   /usr/local/opt/python@3.8/libexec/bin
#
# You can install Python packages with
#   /usr/local/opt/python@3.8/bin/pip3 install <package>
# They will install into the site-package directory
#   /usr/local/lib/python3.8/site-packages
#
# See: https://docs.brew.sh/Homebrew-and-Python
#
# python@3.8 is keg-only, which means it was not symlinked into /usr/local,
# because this is an alternate version of another formula.
#
# If you need to have python@3.8 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/python@3.8/bin:$PATH"' >> ~/.zshrc
#
# For compilers to find python@3.8 you may need to set:
#   export LDFLAGS="-L/usr/local/opt/python@3.8/lib"
#
# For pkg-config to find python@3.8 you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/python@3.8/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/python@3.8/3.8.8_1: 4,375 files, 71.3MB
# Removing: /usr/local/Cellar/python@3.8/3.8.8... (4,375 files, 71.4MB)
# ==> Upgrading imagemagick 7.0.11-1 -> 7.0.11-3
# ==> Downloading https://homebrew.bintray.com/bottles/libomp-11.1.0.catalina.bott
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/45a5aa653bd45bd5ff585
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/imagemagick-7.0.11-3.catali
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/d3cbc778196046e2f833b
# ######################################################################## 100.0%
# ==> Installing dependencies for imagemagick: libomp
# ==> Installing imagemagick dependency: libomp
# ==> Pouring libomp-11.1.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libomp/11.1.0: 9 files, 1.4MB
# ==> Installing imagemagick
# ==> Pouring imagemagick-7.0.11-3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/imagemagick/7.0.11-3: 797 files, 29.7MB
# Removing: /usr/local/Cellar/imagemagick/7.0.11-1... (797 files, 29.7MB)
# Removing: /Users/soma/Library/Caches/Homebrew/imagemagick--7.0.11-1.catalina.bottle.tar.gz... (10.0MB)
# ==> Upgrading youtube-dl 2021.2.22 -> 2021.3.3
# ==> Downloading https://homebrew.bintray.com/bottles/youtube-dl-2021.3.3.catalin
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/872aae1eae8ac261c9030
# ######################################################################## 100.0%
# ==> Pouring youtube-dl-2021.3.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/youtube-dl/2021.3.3: 1,391 files, 13.4MB
# Removing: /usr/local/Cellar/youtube-dl/2020.05.29... (12 files, 2.1MB)
# Removing: /usr/local/Cellar/youtube-dl/2020.06.16.1... (12 files, 2.1MB)
# Removing: /usr/local/Cellar/youtube-dl/2021.2.22... (1,389 files, 13.4MB)
# Removing: /Users/soma/Library/Caches/Homebrew/youtube-dl--2021.2.22.catalina.bottle.tar.gz... (3.5MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> Caveats
# ==> libffi
# libffi is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# For compilers to find libffi you may need to set:
#   export LDFLAGS="-L/usr/local/opt/libffi/lib"
#   export CPPFLAGS="-I/usr/local/opt/libffi/include"
#
# For pkg-config to find libffi you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/libffi/lib/pkgconfig"
#
# ==> python@3.9
# Python has been installed as
#   /usr/local/bin/python3
#
# Unversioned symlinks `python`, `python-config`, `pip` etc. pointing to
# `python3`, `python3-config`, `pip3` etc., respectively, have been installed into
#   /usr/local/opt/python@3.9/libexec/bin
#
# You can install Python packages with
#   pip3 install <package>
# They will install into the site-package directory
#   /usr/local/lib/python3.9/site-packages
#
# See: https://docs.brew.sh/Homebrew-and-Python
# ==> icu4c
# icu4c is keg-only, which means it was not symlinked into /usr/local,
# because macOS provides libicucore.dylib (but nothing else).
#
# If you need to have icu4c first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/icu4c/bin:$PATH"' >> ~/.zshrc
#   echo 'export PATH="/usr/local/opt/icu4c/sbin:$PATH"' >> ~/.zshrc
#
# For compilers to find icu4c you may need to set:
#   export LDFLAGS="-L/usr/local/opt/icu4c/lib"
#   export CPPFLAGS="-I/usr/local/opt/icu4c/include"
#
# For pkg-config to find icu4c you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/icu4c/lib/pkgconfig"
#
# ==> python@3.8
# Python has been installed as
#   /usr/local/opt/python@3.8/bin/python3
#
# Unversioned symlinks `python`, `python-config`, `pip` etc. pointing to
# `python3`, `python3-config`, `pip3` etc., respectively, have been installed into
#   /usr/local/opt/python@3.8/libexec/bin
#
# You can install Python packages with
#   /usr/local/opt/python@3.8/bin/pip3 install <package>
# They will install into the site-package directory
#   /usr/local/lib/python3.8/site-packages
#
# See: https://docs.brew.sh/Homebrew-and-Python
#
# python@3.8 is keg-only, which means it was not symlinked into /usr/local,
# because this is an alternate version of another formula.
#
# If you need to have python@3.8 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/python@3.8/bin:$PATH"' >> ~/.zshrc
#
# For compilers to find python@3.8 you may need to set:
#   export LDFLAGS="-L/usr/local/opt/python@3.8/lib"
#
# For pkg-config to find python@3.8 you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/python@3.8/lib/pkgconfig"

# %%
feature_names=list(X.columns)
label_names = ['not surveillance', 'surveillance']
eli5.show_weights(clf, feature_names=feature_names, target_names=label_names, show=['decision_tree'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <br>
#         <pre><svg width="1230pt" height="671pt"
#  viewBox="0.00 0.00 1229.50 671.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 667)">
# <title>Tree</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-667 1225.5,-667 1225.5,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="835.5,-663 690.5,-663 690.5,-580 835.5,-580 835.5,-663"/>
# <text text-anchor="middle" x="763" y="-647.8" font-family="Times,serif" font-size="14.00">steer2 &lt;= 0.11</text>
# <text text-anchor="middle" x="763" y="-632.8" font-family="Times,serif" font-size="14.00">gini = 0.288</text>
# <text text-anchor="middle" x="763" y="-617.8" font-family="Times,serif" font-size="14.00">samples = 100.0%</text>
# <text text-anchor="middle" x="763" y="-602.8" font-family="Times,serif" font-size="14.00">value = [0.826, 0.174]</text>
# <text text-anchor="middle" x="763" y="-587.8" font-family="Times,serif" font-size="14.00">class = not surveillance</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <polygon fill="none" stroke="black" points="754.5,-544 609.5,-544 609.5,-461 754.5,-461 754.5,-544"/>
# <text text-anchor="middle" x="682" y="-528.8" font-family="Times,serif" font-size="14.00">squawk_1 &lt;= 4380.5</text>
# <text text-anchor="middle" x="682" y="-513.8" font-family="Times,serif" font-size="14.00">gini = 0.107</text>
# <text text-anchor="middle" x="682" y="-498.8" font-family="Times,serif" font-size="14.00">samples = 86.4%</text>
# <text text-anchor="middle" x="682" y="-483.8" font-family="Times,serif" font-size="14.00">value = [0.943, 0.057]</text>
# <text text-anchor="middle" x="682" y="-468.8" font-family="Times,serif" font-size="14.00">class = not surveillance</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M734.9,-579.91C728.74,-571.01 722.16,-561.51 715.81,-552.33"/>
# <polygon fill="black" stroke="black" points="718.62,-550.25 710.05,-544.02 712.87,-554.24 718.62,-550.25"/>
# <text text-anchor="middle" x="705.58" y="-564.92" font-family="Times,serif" font-size="14.00">True</text>
# </g>
# <!-- 20 -->
# <g id="node21" class="node">
# <title>20</title>
# <polygon fill="none" stroke="black" points="915,-544 775,-544 775,-461 915,-461 915,-544"/>
# <text text-anchor="middle" x="845" y="-528.8" font-family="Times,serif" font-size="14.00">boxes2 &lt;= 0.022</text>
# <text text-anchor="middle" x="845" y="-513.8" font-family="Times,serif" font-size="14.00">gini = 0.15</text>
# <text text-anchor="middle" x="845" y="-498.8" font-family="Times,serif" font-size="14.00">samples = 13.6%</text>
# <text text-anchor="middle" x="845" y="-483.8" font-family="Times,serif" font-size="14.00">value = [0.082, 0.918]</text>
# <text text-anchor="middle" x="845" y="-468.8" font-family="Times,serif" font-size="14.00">class = surveillance</text>
# </g>
# <!-- 0&#45;&gt;20 -->
# <g id="edge20" class="edge">
# <title>0&#45;&gt;20</title>
# <path fill="none" stroke="black" d="M791.45,-579.91C797.68,-571.01 804.34,-561.51 810.78,-552.33"/>
# <polygon fill="black" stroke="black" points="813.73,-554.22 816.6,-544.02 808,-550.2 813.73,-554.22"/>
# <text text-anchor="middle" x="820.93" y="-564.94" font-family="Times,serif" font-size="14.00">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <polygon fill="none" stroke="black" points="591.5,-425 446.5,-425 446.5,-342 591.5,-342 591.5,-425"/>
# <text text-anchor="middle" x="519" y="-409.8" font-family="Times,serif" font-size="14.00">duration1 &lt;= 0.358</text>
# <text text-anchor="middle" x="519" y="-394.8" font-family="Times,serif" font-size="14.00">gini = 0.057</text>
# <text text-anchor="middle" x="519" y="-379.8" font-family="Times,serif" font-size="14.00">samples = 76.5%</text>
# <text text-anchor="middle" x="519" y="-364.8" font-family="Times,serif" font-size="14.00">value = [0.971, 0.029]</text>
# <text text-anchor="middle" x="519" y="-349.8" font-family="Times,serif" font-size="14.00">class = not surveillance</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M625.45,-460.91C612.05,-451.29 597.65,-440.95 583.91,-431.09"/>
# <polygon fill="black" stroke="black" points="585.62,-428.01 575.45,-425.02 581.53,-433.7 585.62,-428.01"/>
# </g>
# <!-- 13 -->
# <g id="node14" class="node">
# <title>13</title>
# <polygon fill="none" stroke="black" points="754.5,-425 609.5,-425 609.5,-342 754.5,-342 754.5,-425"/>
# <text text-anchor="middle" x="682" y="-409.8" font-family="Times,serif" font-size="14.00">squawk_1 &lt;= 4465.5</text>
# <text text-anchor="middle" x="682" y="-394.8" font-family="Times,serif" font-size="14.00">gini = 0.397</text>
# <text text-anchor="middle" x="682" y="-379.8" font-family="Times,serif" font-size="14.00">samples = 9.8%</text>
# <text text-anchor="middle" x="682" y="-364.8" font-family="Times,serif" font-size="14.00">value = [0.727, 0.273]</text>
# <text text-anchor="middle" x="682" y="-349.8" font-family="Times,serif" font-size="14.00">class = not surveillance</text>
# </g>
# <!-- 1&#45;&gt;13 -->
# <g id="edge13" class="edge">
# <title>1&#45;&gt;13</title>
# <path fill="none" stroke="black" d="M682,-460.91C682,-452.65 682,-443.86 682,-435.3"/>
# <polygon fill="black" stroke="black" points="685.5,-435.02 682,-425.02 678.5,-435.02 685.5,-435.02"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <polygon fill="none" stroke="black" points="433.5,-306 288.5,-306 288.5,-223 433.5,-223 433.5,-306"/>
# <text text-anchor="middle" x="361" y="-290.8" font-family="Times,serif" font-size="14.00">speed2 &lt;= 0.003</text>
# <text text-anchor="middle" x="361" y="-275.8" font-family="Times,serif" font-size="14.00">gini = 0.007</text>
# <text text-anchor="middle" x="361" y="-260.8" font-family="Times,serif" font-size="14.00">samples = 66.4%</text>
# <text text-anchor="middle" x="361" y="-245.8" font-family="Times,serif" font-size="14.00">value = [0.997, 0.003]</text>
# <text text-anchor="middle" x="361" y="-230.8" font-family="Times,serif" font-size="14.00">class = not surveillance</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge3" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M464.18,-341.91C451.19,-332.29 437.24,-321.95 423.92,-312.09"/>
# <polygon fill="black" stroke="black" points="425.84,-309.16 415.72,-306.02 421.67,-314.78 425.84,-309.16"/>
# </g>
# <!-- 8 -->
# <g id="node9" class="node">
# <title>8</title>
# <polygon fill="none" stroke="black" points="596.5,-306 451.5,-306 451.5,-223 596.5,-223 596.5,-306"/>
# <text text-anchor="middle" x="524" y="-290.8" font-family="Times,serif" font-size="14.00">steer2 &lt;= 0.091</text>
# <text text-anchor="middle" x="524" y="-275.8" font-family="Times,serif" font-size="14.00">gini = 0.32</text>
# <text text-anchor="middle" x="524" y="-260.8" font-family="Times,serif" font-size="14.00">samples = 10.1%</text>
# <text text-anchor="middle" x="524" y="-245.8" font-family="Times,serif" font-size="14.00">value = [0.8, 0.2]</text>
# <text text-anchor="middle" x="524" y="-230.8" font-family="Times,serif" font-size="14.00">class = not surveillance</text>
# </g>
# <!-- 2&#45;&gt;8 -->
# <g id="edge8" class="edge">
# <title>2&#45;&gt;8</title>
# <path fill="none" stroke="black" d="M520.73,-341.91C521.09,-333.56 521.47,-324.67 521.84,-316.02"/>
# <polygon fill="black" stroke="black" points="525.34,-316.16 522.27,-306.02 518.34,-315.86 525.34,-316.16"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <polygon fill="none" stroke="black" points="270.5,-187 125.5,-187 125.5,-104 270.5,-104 270.5,-187"/>
# <text text-anchor="middle" x="198" y="-171.8" font-family="Times,serif" font-size="14.00">duration2 &lt;= 0.155</text>
# <text text-anchor="middle" x="198" y="-156.8" font-family="Times,serif" font-size="

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, max_depth=5)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
clf.score(X_test, y_test)
# Out:
# 0.98

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['not surveil', 'surveil'])
pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                 Predicted not surveil  Predicted surveil
# Is not surveil                    130                  1
# Is surveil                          2                 17

# %% [markdown]
# ## What are the important features?
#
# We'll use slighyl different code for a decision tree, as it likes to draw big pictures if we don't stop it. The code looks like this:
#
# ```python
# import eli5
#
# feature_names=list(X.columns)
# eli5.show_weights(clf, feature_names=feature_names, show=['description', 'feature_importances'])
# ```

# %% [markdown]
# ### Understanding the output
#
# **Why is the feature importance difference than for logistic regression?**
#
# Also, if you don't specify a `max_depth`, that's a LOT of zeroes! It doesn't even use most of the features! **Why not?**

# %% [markdown]
# ## How well does the tree perform?
#
# Display another confusion matrix with your new classifier.

# %% [markdown]
# ## Visualize the tree
#
# You can use `eli5` to visualize the decision tree itself! It usually takes up too much space, but since it's a special occasion we'll let it go.

# %% [markdown]
# If you'd like your graph to have colors colors, or to not use eli5, you can do it the old-fashioned way. You might need to `brew install graphviz` and `pip install graphviz`.
#
# ```python
# from sklearn import tree
# import graphviz
#
# label_names = ['not surveillance', 'surveillance']
# feature_names = X.columns
#
# dot_data = tree.export_graphviz(clf,
#                     feature_names=feature_names,
#                     filled=True,
#                     class_names=label_names)
# graph = graphviz.Source(dot_data)
# graph
# ```
#
# * **Tip:** You'll probably need to scroll sideways a bit

# %% [markdown]
# # One more classifier: Random forest
#
# ## Build and train your classifier
#
# We can build a random forest classifier like this:
#
# ```python
# from sklearn.ensemble import RandomForestClassifier
# clf = RandomForestClassifier()
# ```
#
# But you're in charge of fitting it to your training data!
#
# * **Tip:** You can also set `max_depth` here, but you won't be able to visualize the result.
# * **Tip:** Increase `n_estimators` to 100 to make a better classifier.

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, max_depth=5)
clf.fit(X_train, y_train)

# %% [markdown]
# ## What are the important features?

# %% [markdown]
# ### Understanding the output
#
# What is a random forest, and **why is the feature importance difference than for the decision tree?** Isn't a random forest just like a decision tree or something?

# %% [markdown]
# ## How well does it perform?

# %% [markdown]
# ### How confident do you feel in the model?

# %% [markdown]
# # Actually finding spy planes
#
# Now let's try ot actually find our spy planes
#
# ## Retrain our model
#
# When we did test/train split, we trained our model with only a subset of our data, so we could test with the rest. Now that we're working in the "real world" we want to re-train it using not just `_train` and `_test` data, but instead **everything we have labels for.**

# %%
clf.fit(X, y)

# %% [markdown]
# ## Filter for planes we want to predict
#
# We have a dataframe of features that includes three types of planes:
#
# * Those that are labeled as surveillance planes
# * Those that are labeled as not surveillance
# * Those that aren't labeled
#
# Which do we want to predictions for? **Filter a new dataframe that's just those.**
#
# * **Tip:** Scroll up to see where you created your `train_df`, it's the opposite!

# %% [markdown]
# How many planes do you have in that list? **Confirm it's about 19,200.**

# %% [markdown]
# ## Predicting
#
# Build your `X` - remember you need to drop a few columns - and use that to make a prediction for each plane.
#
# **Assign the prediction into the `predicted` column**.
#
# * **Tip:** Scroll up to see where you created your features for training, it's similar
# * **Tip:** pandas will yell at us about setting values on copies of a slice but it's fine

# %% [markdown]
# ## How many planes did it predict to be surveillance planes?
#
# It should be roughly around 70-80 planes.

# %% [markdown]
# ## But.. what about those other ones? The ones that are just below the threshold?
#
# The cutoff for a prediction of `1` is 50%, but since we have a lot of time we're interested in investigating the top 150. To get the probability for each row, you will use `clf.predict_proba` instead of `clf.predict`. Also, to get the predicted probability for the `1` category, you'll need to add `[:,1]` to the end of the
#
# ```python
# clf.predict_proba(***your features***)[:,1]
# ```
#
# **Create a new column called `predicted_prob` that is the chance that the plane is a surveillance plane.**
#
# * **Tip:** You dropped three columns when using `clf.predict`, but if you drop the same three you'll get an error now. There's now an extra column that you'll need to drop! What is it?

# %% [markdown]
# ### Get the top 200 predictions
#
# Take a look at what the probabilities look like, showing the top 200 planes that are **most likely to be surveillance planes.**
#
# Then save them to a file for later research.

# %% [markdown]
# # Questions

# %% [markdown]
# ### Question 1
#
# What kind of machine learning are we doing here, and why are we doing it?

# %% [markdown]
# ### Question 2
#
# What are a few different ways you can deal with categorical data? Think about how we dealt with race in the reveal regression compared to how we dealt with type in this dataset.

# %% [markdown]
# ### Question 3
#
# Every time we ran a machine learning algorithm on our dataset, we looked at feature importance.
#
# * When might it be important to explain what our model found important?
# * When might it not be important?

# %% [markdown]
# ### Question 4
#
# Using words and not column names, describe what the machine learning algorithm found to be important when identifying surveillance planes.

# %% [markdown]
# ### Question 5
#
# Why did we use test/train split when it would have been more effective to give our model all of the data from the start?

# %% [markdown]
# ### Question 6
#
# Why did we use a random forest instead of a decision tree or logistic regression? Was there something about the data?

# %% [markdown]
# ### Question 7
#
# Why did we use probability instead of just looking for planes with a predicted value of 1? It seems like we should have just trusted the algorithm, right?

# %% [markdown]
# ### Question 8
#
# What if our random forest or input dataset were flawed? What would be the repercussions?

# %% [markdown]
# ### Question 9
#
# The government could claim that we're threatening national security by publishing this paper as well as publishing this code - now anyone could look for planes that are surveilling them. What do you think?

# %% [markdown]
# ### Question 10
#
# We're using data from the past, but you can get real-time flight data from many services. Can you think of any uses for this algorithm using real-time instead of historical data?

# %% [markdown]
# ### Question 11
#
# This isn't a question, but if you look at `candidates.csv` and `candidates-annotates.csv` you can see how Buzzfeed did their research after finding a list of suspicious planes.
